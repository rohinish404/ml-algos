# %%
import pandas as pd
df = pd.read_csv('Desktop/csv_files/heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df1 = df[df.Cholesterol<=(df.Cholesterol.mean()+3*df.Cholesterol.std())]
df1.shape
# Out:
# (915, 12)

# %%
df2 = df1[df1.Oldpeak<=(df1.Oldpeak.mean()+3*df1.Oldpeak.std())]
df2.shape
# Out:
# (909, 12)

# %%
df3 = df2[df2.RestingBP<=(df2.RestingBP.mean()+3*df2.RestingBP.std())]
df3
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df4 = df3.copy()
df4.ExerciseAngina.replace(
    {
        'N': 0,
        'Y': 1
    },
    inplace=True)

df4.ST_Slope.replace(
    {
        'Down': 1,
        'Flat': 2,
        'Up': 3
    },
    inplace=True
)

df4.RestingECG.replace(
    {
        'Normal': 1,
        'ST': 2,
        'LVH': 3
    },
    
    inplace=True)
df4.Sex.replace(
    {
        'M': 0,
        'F': 1
    },
    
    inplace=True)
df4
dummies = pd.get_dummies(df4.ChestPainType)
df5 = pd.concat([df4,dummies],axis='columns')
df5
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0           ATA        140          289          0           1
# 1     49    1           NAP        160          180          0           1
# 2     37    0           ATA        130          283          0           2
# 3     48    1           ASY        138          214          0           1
# 4     54    0           NAP        150          195          0           1
# ..   ...  ...           ...        ...          ...        ...         ...
# 913   45    0            TA        110          264          0           1
# 914   68    0           ASY        144          193          1           1
# 915   57    0           ASY        130          131          0           1
# 916   57    1           ATA        130          236          0           3
# 917   38    0           NAP        138          175          0           1
#
# ...

# %%
df5.drop('ChestPainType',axis='columns', inplace=True)
df5
# Out:
#      Age  Sex  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40    0        140          289          0           1    172
# 1     49    1        160          180          0           1    156
# 2     37    0        130          283          0           2     98
# 3     48    1        138          214          0           1    108
# 4     54    0        150          195          0           1    122
# ..   ...  ...        ...          ...        ...         ...    ...
# 913   45    0        110          264          0           1    132
# 914   68    0        144          193          1           1    141
# 915   57    0        130          131          0           1    115
# 916   57    1        130          236          0           3    174
# 917   38    0        138          175          0           1    173
#
#      ExerciseAngina  Oldpeak  ST_Slope  HeartDisease  ASY  ATA  NAP  TA
# 0                 0      0.0         3             0    0    1    0   0
# ...

# %%
X = df5.drop('HeartDisease',axis='columns')
Y = df5.HeartDisease

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.42896269, -0.51485643,  0.46089071, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-0.47545956,  1.94228905,  1.5925728 , ..., -0.4836591 ,
#          1.86750159, -0.22914788],
#        [-1.74679706, -0.51485643, -0.10495034, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        ...,
#        [ 0.37209878, -0.51485643, -0.10495034, ..., -0.4836591 ,
#         -0.53547478, -0.22914788],
#        [ 0.37209878,  1.94228905, -0.10495034, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-1.64085227, -0.51485643,  0.3477225 , ..., -0.4836591 ,
#          1.86750159, -0.22914788]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_scaled,Y,test_size=0.2)

# %%
from sklearn import svm
from sklearn.model_selection import cross_val_score
scores1 = cross_val_score(svm.SVC(),X_scaled,Y,cv=5)
scores1
# Out:
# array([0.85082873, 0.84530387, 0.82222222, 0.81111111, 0.76666667])

# %%
scores1.mean()
# Out:
# 0.8192265193370165

# %%
from sklearn.ensemble import BaggingClassifier
bag_model = BaggingClassifier(
    base_estimator = svm.SVC(),
    n_estimators=100,
    max_samples = 0.8,
    oob_score=True,
    random_state=0
)
bag_model.fit(x_train,y_train)
cross_val_score(bag_model,X_scaled,Y).mean()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ...

# %%
from sklearn import tree
scores2 = cross_val_score(tree.DecisionTreeClassifier(),X_scaled,Y)

# %%
scores2.mean()
# Out:
# 0.7460405156537753

# %%
bag_model2 = BaggingClassifier(
    base_estimator = tree.DecisionTreeClassifier(),
    n_estimators=50,
    max_samples = 0.8,
    oob_score=True,
    random_state=0
)
bag_model2.fit(x_train,y_train)
cross_val_score(bag_model2,X_scaled,Y).mean()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

scores3 = cross_val_score(RandomForestClassifier(), X_scaled, Y, cv=5)
scores3.mean()
# Out:
# 0.8303069367710251
